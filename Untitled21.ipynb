# %% [markdown]
# <a href="https://colab.research.google.com/github/wop27812-creator/Python-/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Football Game Statistics Simulator
#
# This script simulates a football match between two teams, generates player and team statistics, and presents them using pandas DataFrames. This can serve as a foundation for building more complex statistical analysis for a football game.

# %%
import random
import pandas as pd

# --- Configuration --- #
TOTAL_GAME_EVENTS = 100 # Number of events in a game

# --- Helper Functions --- #

def get_weighted_random_player(players, attribute_key):
    """Selects a player based on a weighted random attribute."""
    # Use getattr to access player attributes dynamically
    weights = [getattr(player, attribute_key) for player in players]
    total_weight = sum(weights)
    if total_weight == 0: # Handle case where all weights are zero
        return random.choice(players)
    normalized_weights = [w / total_weight for w in weights]
    return random.choices(players, weights=normalized_weights, k=1)[0]

class Player:
    def __init__(self, name, offense, defense, stamina):
        self.name = name
        self.offense = offense
        self.defense = defense
        self.stamina = stamina
        self.stats = {
            'goals': 0,
            'assists': 0,
            'shots': 0,
            'passes': 0,
            'tackles': 0,
            'interceptions': 0,
            'fouls_committed': 0,
            'fouls_suffered': 0,
            'possession_time': 0 # in arbitrary units
        }

    def __repr__(self):
        return f"Player(name='{self.name}', offense={self.offense}, defense={self.defense})"

class Team:
    def __init__(self, name, players):
        self.name = name
        self.players = players
        self.score = 0
        self.possession = 0 # in arbitrary units
        self.stats = {
            'goals_scored': 0,
            'shots_on_target': 0,
            'shots_off_target': 0,
            'passes_completed': 0,
            'passes_attempted': 0,
            'tackles_won': 0,
            'interceptions_made': 0,
            'fouls_committed': 0,
            'fouls_suffered': 0,
            'possession_percentage': 0.0
        }

    def get_offensive_players(self):
        return sorted(self.players, key=lambda p: p.offense, reverse=True)

    def get_defensive_players(self):
        return sorted(self.players, key=lambda p: p.defense, reverse=True)

    def __repr__(self):
        return f"Team(name='{self.name}', score={self.score})"


def simulate_game_event(team_a, team_b):
    """Simulates a single event within the game."""

    # Determine which team has possession based on a rough probability
    # For simplicity, start with 50/50 and adjust based on previous possession
    if team_a.possession >= team_b.possession:
        current_possessor = random.choices([team_a, team_b], weights=[0.4, 0.6], k=1)[0]
    else:
        current_possessor = random.choices([team_a, team_b], weights=[0.6, 0.4], k=1)[0]

    opponent_team = team_a if current_possessor == team_b else team_b

    # Assign possession time (arbitrary unit)
    possession_duration = random.randint(1, 10)
    current_possessor.possession += possession_duration

    # Select a player for the action from the possessing team
    action_player = get_weighted_random_player(current_possessor.players, 'offense')
    action_player.stats['possession_time'] += possession_duration

    event_type = random.choices(
        ['pass', 'shot', 'tackle', 'foul', 'interception'],
        weights=[0.4, 0.3, 0.15, 0.1, 0.05], k=1)[0]

    if event_type == 'pass':
        action_player.stats['passes'] += 1
        current_possessor.stats['passes_attempted'] += 1
        if random.random() < 0.75: # 75% pass completion rate
            current_possessor.stats['passes_completed'] += 1
            # Simulate another player receiving an assist chance
            if random.random() < 0.3: # 30% chance for an assist opportunity after a successful pass
                receiver = get_weighted_random_player(current_possessor.players, 'offense')
                if receiver != action_player and random.random() < 0.5: # 50% chance if different player
                    receiver.stats['assists'] += 1

    elif event_type == 'shot':
        action_player.stats['shots'] += 1

        # Select a defensive player from the opponent to contest the shot
        defensive_player = get_weighted_random_player(opponent_team.players, 'defense')

        # Shot success depends on offensive player's skill vs. defensive player's skill
        shot_chance = action_player.offense * 0.1 - defensive_player.defense * 0.05 + random.uniform(0.1, 0.5)

        if shot_chance > 0.6: # Goal!
            current_possessor.score += 1
            current_possessor.stats['goals_scored'] += 1
            action_player.stats['goals'] += 1
            current_possessor.stats['shots_on_target'] += 1
        elif shot_chance > 0.3: # Shot on target, but saved/missed by small margin
            current_possessor.stats['shots_on_target'] += 1
        else: # Shot off target
            current_possessor.stats['shots_off_target'] += 1

    elif event_type == 'tackle':
        # An offensive player attempts to tackle an opposing player
        tackler = get_weighted_random_player(opponent_team.players, 'defense') # Opponent player tries to tackle
        action_player.stats['fouls_suffered'] += 1
        tackler.stats['tackles'] += 1

        if random.random() < 0.6: # 60% chance tackle is successful
            opponent_team.stats['tackles_won'] += 1
            # Possession might switch, but for simplicity, let's just record the tackle
        else:
            # Missed tackle, possibly a foul
            if random.random() < 0.4: # 40% chance of foul on missed tackle
                tackler.stats['fouls_committed'] += 1
                opponent_team.stats['fouls_committed'] += 1

    elif event_type == 'interception':
        interceptor = get_weighted_random_player(opponent_team.players, 'defense')
        interceptor.stats['interceptions'] += 1
        opponent_team.stats['interceptions_made'] += 1
        # Possession changes
        current_possessor.possession -= possession_duration # Subtract, as they lost possession
        opponent_team.possession += possession_duration # Add to new possessor

    elif event_type == 'foul':
        fouler = get_weighted_random_player(current_possessor.players, 'defense') # Defensive player from possessing team commits foul
        fouler.stats['fouls_committed'] += 1
        current_possessor.stats['fouls_committed'] += 1
        # Opponent suffers foul
        fouled_player = get_weighted_random_player(opponent_team.players, 'offense')
        fouled_player.stats['fouls_suffered'] += 1
        opponent_team.stats['fouls_suffered'] += 1


def run_simulation(team_a, team_b, num_events):
    """Runs the full game simulation."""
    for _ in range(num_events):
        simulate_game_event(team_a, team_b)

    # Calculate possession percentage
    total_possession_time = team_a.possession + team_b.possession
    if total_possession_time > 0:
        team_a.stats['possession_percentage'] = (team_a.possession / total_possession_time) * 100
        team_b.stats['possession_percentage'] = (team_b.possession / total_possession_time) * 100

    print(f"\n--- Match Result: {team_a.name} {team_a.score} - {team_b.score} {team_b.name} ---")


def display_player_statistics(team):
    """Displays individual player statistics for a team."""
    player_data = []
    for player in team.players:
        player_data.append({
            'Player': player.name,
            'Goals': player.stats['goals'],
            'Assists': player.stats['assists'],
            'Shots': player.stats['shots'],
            'Passes': player.stats['passes'],
            'Tackles': player.stats['tackles'],
            'Interceptions': player.stats['interceptions'],
            'Fouls Committed': player.stats['fouls_committed'],
            'Fouls Suffered': player.stats['fouls_suffered'],
            'Possession Time': player.stats['possession_time']
        })
    df = pd.DataFrame(player_data)
    print(f"\n--- {team.name} Player Statistics ---")
    display(df.set_index('Player'))


def display_team_statistics(team):
    """Displays overall team statistics."""
    team_data = [{
        'Team': team.name,
        'Goals Scored': team.stats['goals_scored'],
        'Shots on Target': team.stats['shots_on_target'],
        'Shots off Target': team.stats['shots_off_target'],
        'Passes Completed': team.stats['passes_completed'],
        'Passes Attempted': team.stats['passes_attempted'],
        'Tackles Won': team.stats['tackles_won'],
        'Interceptions Made': team.stats['interceptions_made'],
        'Fouls Committed': team.stats['fouls_committed'],
        'Fouls Suffered': team.stats['fouls_suffered'],
        'Possession %': f"{team.stats['possession_percentage']:.2f}%"
    }]
    df = pd.DataFrame(team_data)
    print(f"\n--- {team.name} Overall Team Statistics ---")
    display(df.set_index('Team'))

# --- Create Players --- #

# Team A Players
player1_a = Player("Leo Messi", 95, 30, 85)
player2_a = Player("Kylian Mbappe", 90, 40, 90)
player3_a = Player("Sergio Ramos", 60, 90, 75)
player4_a = Player("Kevin De Bruyne", 88, 55, 88)
player5_a = Player("Virgil van Dijk", 50, 92, 80)

team_a_players = [player1_a, player2_a, player3_a, player4_a, player5_a]

# Team B Players
player1_b = Player("Cristiano Ronaldo", 92, 35, 88)
player2_b = Player("Erling Haaland", 90, 30, 87)
player3_b = Player("Ruben Dias", 55, 91, 78)
player4_b = Player("Luka Modric", 85, 60, 85)
player5_b = Player("Achraf Hakimi", 75, 80, 92)

team_b_players = [player1_b, player2_b, player3_b, player4_b, player5_b]

# --- Create Teams --- #
team_a = Team("FC Alpha", team_a_players)
team_b = Team("Sporting Beta", team_b_players)

# --- Run Simulation --- #
print(f"Starting football match simulation between {team_a.name} and {team_b.name}...")
run_simulation(team_a, team_b, TOTAL_GAME_EVENTS)

# --- Display Statistics --- #
display_team_statistics(team_a)
display_player_statistics(team_a)

display_team_statistics(team_b)
display_player_statistics(team_b)
# Out:
# Starting football match simulation between FC Alpha and Sporting Beta...
#
# --- Match Result: FC Alpha 15 - 20 Sporting Beta ---
#
# --- FC Alpha Overall Team Statistics ---
#           Goals Scored  Shots on Target  Shots off Target  Passes Completed  \
# Team
# FC Alpha            15               15                 0                14
#
#           Passes Attempted  Tackles Won  Interceptions Made  Fouls Committed  \
# Team
# FC Alpha                21            3                   3                7
#
#           Fouls Suffered Possession %
# Team
# FC Alpha               6       49.17%
# --- FC Alpha Player Statistics ---
#                  Goals  Assists  Shots  Passes  Tackles  Interceptions  \
# Player
# Leo Messi            5        1      5       6        1              0
# Kylian Mbappe        6        1      6       5        1              0
# Sergio Ramos         0        0      0       2        1              0
# Kevin De Bruyne      1        0      1       6        0              2
# Virgil van Dijk      3        0      3       2        1              1
#
#                  Fouls Committed  Fouls Suffered  Possession Time
# Player
# Leo Messi                      0               2               73
# Kylian Mbappe                  1               1               92
# Sergio Ramos                   2               3               29
# Kevin De Bruyne                2               1               44
# Virgil van Dijk                2               2               45
# --- Sporting Beta Overall Team Statistics ---
#                Goals Scored  Shots on Target  Shots off Target  \
# Team
# Sporting Beta            20               20                 0
#
#                Passes Completed  Passes Attempted  Tackles Won  \
# Team
# Sporting Beta                15                17            2
#
#                Interceptions Made  Fouls Committed  Fouls Suffered  \
# Team
# Sporting Beta                   5                6               6
#
#               Possession %
# Team
# Sporting Beta       50.83%
# --- Sporting Beta Player Statistics ---
#                    Goals  Assists  Shots  Passes  Tackles  Interceptions  \
# Player
# Cristiano Ronaldo      5        0      5       5        0              0
# Erling Haaland         4        0      4       6        0              1
# Ruben Dias             2        0      2       1        1              2
# Luka Modric            5        0      5       4        0              0
# Achraf Hakimi          4        0      4       1        2              2
#
#                    Fouls Committed  Fouls Suffered  Possession Time
# Player
# Cristiano Ronaldo                1               4              100
# Erling Haaland                   0               4               58
# Ruben Dias                       3               0               17
# Luka Modric                      1               1               48
# Achraf Hakimi                    1               1               37

# %%
To copy this Colab notebook to your GitHub repository, follow these steps:

1.  **Go to File > Save a copy in GitHub**.
2.  A new window will appear asking you to authorize Colab to access your GitHub account (if you haven't done so already).
3.  After authorization, you can select your GitHub repository and specify a file name for your notebook. You can also choose to include a commit message.
4.  Click 'OK' or 'Save' to commit the notebook to your chosen GitHub repository.

Alternatively, you can first download the `.ipynb` file and then manually upload it to your GitHub repository:

1.  **Go to File > Download > Download .ipynb**.
2.  This will download the notebook file to your local computer.
3.  Then, navigate to your desired GitHub repository in your web browser and use the 'Add file' > 'Upload files' option to upload the downloaded `.ipynb` file.
